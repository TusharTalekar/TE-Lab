# %%
import numpy as np
import pandas as pd
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
# from sklearn.feature_extraction.learn import TFidVectorizer
import math

# %%
# with open('para.txt', 'r', encoding='utf-8') as f: doc = f.read() 
doc='''Natural Language Processing (NLP) is a field of artificial intelligence that focuses on the interaction between computers and humans through natural language. The ultimate goal of NLP is to enable computers to understand, interpret, and generate human language in a way that is both meaningful and useful.

Key tasks in NLP include tokenization, which breaks text into words or sentences; POS tagging, which identifies parts of speech; stop words removal to filter common words; stemming to reduce words to their root form; and lemmatization, which normalizes words to their base or dictionary form.

Applications of NLP span various domains such as sentiment analysis, machine translation, chatbots, and text summarization.
'''
print(doc)    


nltk.download('averaged_perceptron_tagger') 
nltk.download('wordnet')      
nltk.download('omw-1.4') 
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('tagsets_json')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# Natural Language Processing (NLP) is a field of artificial intelligence that focuses on the interaction between computers and humans through natural language. The ultimate goal of NLP is to enable computers to understand, interpret, and generate human language in a way that is both meaningful and useful.
#
# Key tasks in NLP include tokenization, which breaks text into words or sentences; POS tagging, which identifies parts of speech; stop words removal to filter common words; stemming to reduce words to their root form; and lemmatization, which normalizes words to their base or dictionary form.
#
# Applications of NLP span various domains such as sentiment analysis, machine translation, chatbots, and text summarization.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/te/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/te/nltk_data...
# ...

# %%
# from nltk.tokenize import sent_tokenize
# # Download punkt tokenizer data (one-time, if not done)
# nltk.download('punkt')


# Sentence
sentTokens = nltk.sent_tokenize(doc)
for i in sentTokens:
    print(i)
    print()
# Out:
# Natural Language Processing (NLP) is a field of artificial intelligence that focuses on the interaction between computers and humans through natural language.
#
# The ultimate goal of NLP is to enable computers to understand, interpret, and generate human language in a way that is both meaningful and useful.
#
# Key tasks in NLP include tokenization, which breaks text into words or sentences; POS tagging, which identifies parts of speech; stop words removal to filter common words; stemming to reduce words to their root form; and lemmatization, which normalizes words to their base or dictionary form.
#
# Applications of NLP span various domains such as sentiment analysis, machine translation, chatbots, and text summarization.

# %%
# Word
wordTokens = nltk.word_tokenize(doc)
print(wordTokens)
# for i in wordTokens:
    # print(i,end=" ")
# Out:
# ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'field', 'of', 'artificial', 'intelligence', 'that', 'focuses', 'on', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'through', 'natural', 'language', '.', 'The', 'ultimate', 'goal', 'of', 'NLP', 'is', 'to', 'enable', 'computers', 'to', 'understand', ',', 'interpret', ',', 'and', 'generate', 'human', 'language', 'in', 'a', 'way', 'that', 'is', 'both', 'meaningful', 'and', 'useful', '.', 'Key', 'tasks', 'in', 'NLP', 'include', 'tokenization', ',', 'which', 'breaks', 'text', 'into', 'words', 'or', 'sentences', ';', 'POS', 'tagging', ',', 'which', 'identifies', 'parts', 'of', 'speech', ';', 'stop', 'words', 'removal', 'to', 'filter', 'common', 'words', ';', 'stemming', 'to', 'reduce', 'words', 'to', 'their', 'root', 'form', ';', 'and', 'lemmatization', ',', 'which', 'normalizes', 'words', 'to', 'their', 'base', 'or', 'dictionary', 'form', '.', 'Applications', 'of', 'NLP', 'span', 'various', 'domains', 'suc
# ...

# %%
# StopWords

# from nltk.corpus import stopwords
# nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
stop_words.update(['(',')','.',';',','])
print(type(stop_words))
newTokens=[word for word in wordTokens if word not in stop_words]
print(type(newTokens))
print(newTokens)
# Out:
# <class 'set'>
# <class 'list'>
# ['Natural', 'Language', 'Processing', 'NLP', 'field', 'artificial', 'intelligence', 'focuses', 'interaction', 'computers', 'humans', 'natural', 'language', 'The', 'ultimate', 'goal', 'NLP', 'enable', 'computers', 'understand', 'interpret', 'generate', 'human', 'language', 'way', 'meaningful', 'useful', 'Key', 'tasks', 'NLP', 'include', 'tokenization', 'breaks', 'text', 'words', 'sentences', 'POS', 'tagging', 'identifies', 'parts', 'speech', 'stop', 'words', 'removal', 'filter', 'common', 'words', 'stemming', 'reduce', 'words', 'root', 'form', 'lemmatization', 'normalizes', 'words', 'base', 'dictionary', 'form', 'Applications', 'NLP', 'span', 'various', 'domains', 'sentiment', 'analysis', 'machine', 'translation', 'chatbots', 'text', 'summarization']

# %%
# Stemming is a normalization technique where lists of tokenized words are converted into shortened root words to remove redundancy. Stemming is the process of reducing inflected (or sometimes derived) words to their word stem, base or root form.
# E.g.
# A stemmer reduces the words like fishing, fished, and fisher to the stem fish.
# The stem need not be a word, for example the Porter algorithm reduces, argue,
# argued, argues, arguing, and argus to the stem argu.


# Lemmatization in NLTK is the algorithmic process of finding the lemma of a word depending on its meaning and context. Lemmatization usually refers to the morphological analysis of words, which aims to remove inflectional endings. It helps in returning the base or dictionary form of a word known as the lemma.
# Eg. Lemma for studies is study


# Stemming algorithm works by cutting the suffix from the word. In a broader sense cuts either the beginning or end of the word.
# On the contrary, Lemmatization is a more powerful operation, and it takes into consideration morphological analysis of the words.

# %%
# Stemming
# from nltk.stem import PorterStemmer

# words=['dream','dreaming','dreamed']
words=['studying','study','daytime','daytiming','e','exiting','exited','exitsd','dream','dreaming','dreamed']
ps=nltk.PorterStemmer()
for w in words:
    # rootWord=ps.stem(w)
    print(f"{w} → {ps.stem(w)}")
# print(rootWord)
print(f" → {PorterStemmer().stem('dreaming')}")
# Out:
# studying → studi
# study → studi
# daytime → daytim
# daytiming → daytim
# e → e
# exiting → exit
# exited → exit
# exitsd → exitsd
# dream → dream
# dreaming → dream
# dreamed → dream
#  → dream

# %%
# Lematixation
# from nltk.stem import WordNetLemmatizer
# nltk.download('wordnet')      
# nltk.download('omw-1.4')  

wl=WordNetLemmatizer()

text = "studies studying cries cry"
tokenization = nltk.word_tokenize(text)
for w in tokenization:
    print("Lemma for {} is {}".format(w,wl.lemmatize(w)))

print()
tokenization = nltk.word_tokenize(doc)
for w in tokenization:
    if w != wl.lemmatize(w):
        print("{} -> {}".format(w,WordNetLemmatizer().lemmatize(w)))

WordNetLemmatizer().lemmatize('studies')
# Out:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry
#
# focuses -> focus
# computers -> computer
# humans -> human
# computers -> computer
# tasks -> task
# breaks -> break
# words -> word
# sentences -> sentence
# parts -> part
# words -> word
# words -> word
# words -> word
# words -> word
# domains -> domain
# as -> a
# 'study'

# %%
# 2.4. POS Tagging
# POS (Parts of Speech) tell us about grammatical information of words of the sentence by assigning specific token (Determiner, noun, adjective , adverb , verb,Personal Pronoun etc.) as tag (DT,NN ,JJ,RB,VB,PRP etc) to each words.
# Word can have more than one POS depending upon the context where it is used.
# We can use POS tags as statistical NLP tasks. It distinguishes a sense of word which is very helpful in text realization and infer semantic information from text for sentiment analysis

# Working of POS Tagging
# Let’s see various steps involved in POS tagging:

# Tokenization: The input text is split into individual tokens (words or subwords), this step is necessary for further analysis.
# Preprocessing: The text is cleaned such as converting it to lowercase and removing special characters, to improve accuracy.
# Loading a Language Model: Tools like NLTK or SpaCy use pre-trained language models to understand the grammatical rules of the language, these models have been trained on large datasets.
# Linguistic Analysis: The structure of the sentence is analyzed to understand the role of each word in context.
# POS Tagging: Each word is assigned a part-of-speech label based on its role in the sentence and the context provided by surrounding words.
# Evaluation: The results are checked for accuracy. If there are any errors or misclassifications, they are corrected.

# Noun (NN)
# Verb (VB)
# Adjective (JJ)
# Adverb (RB)
# Pronoun (PRP)
# Preposition (IN)
# Conjunction (CC)
# Determiner (DT)
# Interjection (UH)
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
# from nltk.tokenize import word_tokenize
# nltk.download('averaged_perceptron_tagger') 

words=word_tokenize(doc)
# for word in words:
#     print(nltk.pos_tag([word]))

print(nltk.pos_tag(newTokens))
# for word in newTokens:
#     print(nltk.pos_tag([word]))
# Out:
# [('Natural', 'JJ'), ('Language', 'NNP'), ('Processing', 'NNP'), ('NLP', 'NNP'), ('field', 'NN'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('focuses', 'VBZ'), ('interaction', 'NN'), ('computers', 'NNS'), ('humans', 'VBZ'), ('natural', 'JJ'), ('language', 'NN'), ('The', 'DT'), ('ultimate', 'JJ'), ('goal', 'NN'), ('NLP', 'NNP'), ('enable', 'JJ'), ('computers', 'NNS'), ('understand', 'VBP'), ('interpret', 'JJ'), ('generate', 'NN'), ('human', 'JJ'), ('language', 'NN'), ('way', 'NN'), ('meaningful', 'JJ'), ('useful', 'JJ'), ('Key', 'NNP'), ('tasks', 'NNS'), ('NLP', 'NNP'), ('include', 'VBP'), ('tokenization', 'NN'), ('breaks', 'NNS'), ('text', 'JJ'), ('words', 'NNS'), ('sentences', 'NNS'), ('POS', 'NNP'), ('tagging', 'VBG'), ('identifies', 'NNS'), ('parts', 'NNS'), ('speech', 'VBP'), ('stop', 'VB'), ('words', 'NNS'), ('removal', 'JJ'), ('filter', 'JJ'), ('common', 'JJ'), ('words', 'NNS'), ('stemming', 'VBG'), ('reduce', 'VB'), ('words', 'NNS'), ('root', 'JJ'), ('form', 'JJ'), ('lemmat
# ...

# %%
# Term Frequency (TF)
# It is a measure of the frequency of a word (w) in a document (d). TF is defined as
# the ratio of a word’s occurrence in a document to the total number of words in a
# document. The denominator term in the formula is to normalize since all the
# corpus documents are of different lengths.

# Inverse Document Frequency (IDF)
# It is the measure of the importance of a word. Term frequency (TF) does not
# consider the importance of words. Some words such as’ of’, ‘and’, etc. can be
# most frequently present but are of little significance. IDF provides weightage to
# each word based on its frequency in the corpus D.

# Term Frequency — Inverse Document Frequency (TFIDF)
# It is the product of TF and IDF.
# TFIDF gives more weightage to the word that is rare in the corpus (all the documents).
# TFIDF provides more importance to the word that is more frequent in the document.


# After applying TFIDF, text in A and B documents can be represented as a TFIDF vector of
# dimension equal to the vocabulary words. The value corresponding to each word represents
# the importance of that word in a particular document.
# TFIDF is the product of TF with IDF. Since TF values lie between 0 and 1, not using ln can
# result in high IDF for some words, thereby dominating the TFIDF. We don’t want that, and
# therefore, we use ln so that the IDF should not completely dominate the TFIDF.

# %%
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
documentA = 'Jupiter is the largest Planet'
documentB = 'Mars is the fourth Planet from the Sun'
bagOfWordsA=documentA.split(' ')
bagOfWordsB=documentB.split(' ')
print(bagOfWordsA)
print(bagOfWordsB)
uniqueWords=set(bagOfWordsA).union(set(bagOfWordsB))
print(uniqueWords)

numOfWordsA=dict.fromkeys(uniqueWords,0)
numOfWordsB=dict.fromkeys(uniqueWords,0)
for word in bagOfWordsA:
    numOfWordsA[word]+=1
for word in bagOfWordsB:
    numOfWordsB[word]+=1

print(numOfWordsA)
print(numOfWordsB)
# Out:
# ['Jupiter', 'is', 'the', 'largest', 'Planet']
# ['Mars', 'is', 'the', 'fourth', 'Planet', 'from', 'the', 'Sun']
# {'fourth', 'the', 'Sun', 'from', 'is', 'Jupiter', 'Planet', 'Mars', 'largest'}
# {'fourth': 0, 'the': 1, 'Sun': 0, 'from': 0, 'is': 1, 'Jupiter': 1, 'Planet': 1, 'Mars': 0, 'largest': 1}
# {'fourth': 1, 'the': 2, 'Sun': 1, 'from': 1, 'is': 1, 'Jupiter': 0, 'Planet': 1, 'Mars': 1, 'largest': 0}

# %%
# Term Frequency (TF)
def calculateTF(wordCnt,bagOfWords):
    res={}
    n=len(bagOfWords)
    for word,cnt in wordCnt.items():
        res[word]=cnt/n
    return res

tfA=calculateTF(numOfWordsA,bagOfWordsA)
tfB=calculateTF(numOfWordsB,bagOfWordsB)

print(tfA)
print(tfB)
# Out:
# {'fourth': 0.0, 'the': 0.2, 'Sun': 0.0, 'from': 0.0, 'is': 0.2, 'Jupiter': 0.2, 'Planet': 0.2, 'Mars': 0.0, 'largest': 0.2}
# {'fourth': 0.125, 'the': 0.25, 'Sun': 0.125, 'from': 0.125, 'is': 0.125, 'Jupiter': 0.0, 'Planet': 0.125, 'Mars': 0.125, 'largest': 0.0}

# %%
# Inverse Document Frequency (IDF)
# import math
def calculateIDF(documents):
    N=len(documents)
    res=dict.fromkeys(documents[0].keys(),0)
    for document in documents:
        for word,cnt in document.items():
            if cnt>0:
                res[word]+=1
    for w,val in res.items():
        res[w]=round(math.log(N/float(val)),3)
    return res

idfs=calculateIDF([numOfWordsA,numOfWordsB])
print(idfs)
# Out:
# {'fourth': 0.693, 'the': 0.0, 'Sun': 0.693, 'from': 0.693, 'is': 0.0, 'Jupiter': 0.693, 'Planet': 0.0, 'Mars': 0.693, 'largest': 0.693}

# %%
# Term Frequency — Inverse Document Frequency (TFIDF)
def calculateTFIDF(tfBag,idfs):
    res={}
    for w,val in tfBag.items():
        res[w]=tfBag[w]*idfs[w]
    return res

tfidfA=calculateTFIDF(tfA,idfs)
tfidfB=calculateTFIDF(tfB,idfs)

print(tfidfA)
print(tfidfB)
# Out:
# {'fourth': 0.0, 'the': 0.0, 'Sun': 0.0, 'from': 0.0, 'is': 0.0, 'Jupiter': 0.1386, 'Planet': 0.0, 'Mars': 0.0, 'largest': 0.1386}
# {'fourth': 0.086625, 'the': 0.0, 'Sun': 0.086625, 'from': 0.086625, 'is': 0.0, 'Jupiter': 0.0, 'Planet': 0.0, 'Mars': 0.086625, 'largest': 0.0}

# %%
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
documentA = 'Jupiter is Planet'
documentB = 'Mars is the fourth Planet'
bagOfWordsA=documentA.split(' ')
bagOfWordsB=documentB.split(' ')
print(bagOfWordsA)
print(bagOfWordsB)
uniqueWords=set(bagOfWordsA).union(set(bagOfWordsB))
print(uniqueWords)

numOfWordsA=dict.fromkeys(uniqueWords,0)
numOfWordsB=dict.fromkeys(uniqueWords,0)
for word in bagOfWordsA:
    numOfWordsA[word]+=1
for word in bagOfWordsB:
    numOfWordsB[word]+=1

print(numOfWordsA)
print(numOfWordsB)

print('TF')
tfA=calculateTF(numOfWordsA,bagOfWordsA)
tfB=calculateTF(numOfWordsB,bagOfWordsB)
print(tfA)
print(tfB)
print('IDF')
idfs=calculateIDF([numOfWordsA,numOfWordsB])
print(idfs)
print('TFIDF')
tfidfA=calculateTFIDF(tfA,idfs)
tfidfB=calculateTFIDF(tfB,idfs)
print(tfidfA)
print(tfidfB)
# Out:
# ['Jupiter', 'is', 'Planet']
# ['Mars', 'is', 'the', 'fourth', 'Planet']
# {'fourth', 'the', 'is', 'Jupiter', 'Planet', 'Mars'}
# {'fourth': 0, 'the': 0, 'is': 1, 'Jupiter': 1, 'Planet': 1, 'Mars': 0}
# {'fourth': 1, 'the': 1, 'is': 1, 'Jupiter': 0, 'Planet': 1, 'Mars': 1}
# TF
# {'fourth': 0.0, 'the': 0.0, 'is': 0.3333333333333333, 'Jupiter': 0.3333333333333333, 'Planet': 0.3333333333333333, 'Mars': 0.0}
# {'fourth': 0.2, 'the': 0.2, 'is': 0.2, 'Jupiter': 0.0, 'Planet': 0.2, 'Mars': 0.2}
# IDF
# {'fourth': 0.693, 'the': 0.693, 'is': 0.0, 'Jupiter': 0.693, 'Planet': 0.0, 'Mars': 0.693}
# TFIDF
# {'fourth': 0.0, 'the': 0.0, 'is': 0.0, 'Jupiter': 0.23099999999999998, 'Planet': 0.0, 'Mars': 0.0}
# {'fourth': 0.1386, 'the': 0.1386, 'is': 0.0, 'Jupiter': 0.0, 'Planet': 0.0, 'Mars': 0.1386}
